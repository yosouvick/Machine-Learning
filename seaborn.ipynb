# %%
import seaborn as sns
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
plt.style.use('fivethirtyeight')

# %%
data=sns.load_dataset('tips')

# %%
data
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
#plot a scatter plot between total bill and tips

# %%
sns.relplot(data=data,x='total_bill',y='tip',kind='scatter')

# %%
#the hue parameter

# %%
sns.relplot(data=data,x='total_bill',y='tip',kind='scatter',hue='smoker')

# %%
#the style parameter

# %%
sns.relplot(data=data,x='total_bill',y='tip',kind='scatter',hue='smoker',style='sex')

# %%
#the size parameter

# %%
sns.relplot(data=data,x='total_bill',y='tip',kind='scatter',hue='smoker',style='sex',size='size')

# %%
sns.scatterplot(data=data,x='total_bill',y='tip')
# Out:
# <AxesSubplot: xlabel='total_bill', ylabel='tip'>

# %% [markdown]
# # Categorical scatterplots

# %%
#x axis->categorical data
#y axis->neumerical data

# %%
plt.style.use('fivethirtyeight')

# %%
sns.catplot(data=data,x='day',y='tip',kind='strip',jitter=0)

# %%
sns.catplot(data=data,x='day',y='tip',kind='swarm')
# Out:
# C:\Users\Riya\anaconda3\lib\site-packages\seaborn\categorical.py:3544: UserWarning: 8.1% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\Riya\anaconda3\lib\site-packages\seaborn\categorical.py:3544: UserWarning: 6.9% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
sns.catplot(data=data,x='day',y='tip',kind='swarm',hue='sex')
# Out:
# C:\Users\Riya\anaconda3\lib\site-packages\seaborn\categorical.py:3544: UserWarning: 8.1% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\Riya\anaconda3\lib\site-packages\seaborn\categorical.py:3544: UserWarning: 6.9% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\Riya\anaconda3\lib\site-packages\seaborn\categorical.py:3544: UserWarning: 8.1% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\Riya\anaconda3\lib\site-packages\seaborn\categorical.py:3544: UserWarning: 6.9% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# ...

# %%
sns.swarmplot(data=data,x='day',y='tip',hue='sex')
# Out:
# <AxesSubplot: xlabel='day', ylabel='tip'>

# %% [markdown]
# # Boxplot

# %%
#only done in neumerical columns

# %%
#univariate analysis

# %%
sns.boxplot(x=data['tip'])
# Out:
# <AxesSubplot: xlabel='tip'>

# %%
sns.boxplot(x=data['total_bill'])
# Out:
# <AxesSubplot: xlabel='total_bill'>

# %%
sns.catplot(data=data,x='day',y='total_bill',kind='box')

# %%
sns.catplot(data=data,x='day',y='total_bill',kind='box',hue='sex')

# %% [markdown]
# # Violinplot

# %%
sns.violinplot(x=data['total_bill'])
# Out:
# <AxesSubplot: xlabel='total_bill'>

# %%
sns.catplot(x='day',y='total_bill',data=data,kind='violin',hue='sex')

# %%
sns.catplot(x='day',y='total_bill',data=data,kind='violin',hue='sex',split=True)

# %% [markdown]
# # Barplot

# %%
sns.catplot(data=data,x='smoker',y='total_bill',kind='bar',hue='sex')

# %%
sns.catplot(data=data,x='smoker',y='total_bill',kind='bar',estimator=np.std,hue='sex')

# %%
sns.catplot(data=data,x='sex',kind='count',hue='smoker')

# %%
flights=sns.load_dataset('flights')

# %%
flights.head()
# Out:
#    year month  passengers
# 0  1949   Jan         112
# 1  1949   Feb         118
# 2  1949   Mar         132
# 3  1949   Apr         129
# 4  1949   May         121

# %%
x=flights.pivot_table(index='year',columns='month',values='passengers',aggfunc='sum')

# %%
x
# Out:
# month  Jan  Feb  Mar  Apr  May  Jun  Jul  Aug  Sep  Oct  Nov  Dec
# year
# 1949   112  118  132  129  121  135  148  148  136  119  104  118
# 1950   115  126  141  135  125  149  170  170  158  133  114  140
# 1951   145  150  178  163  172  178  199  199  184  162  146  166
# 1952   171  180  193  181  183  218  230  242  209  191  172  194
# 1953   196  196  236  235  229  243  264  272  237  211  180  201
# 1954   204  188  235  227  234  264  302  293  259  229  203  229
# 1955   242  233  267  269  270  315  364  347  312  274  237  278
# 1956   284  277  317  313  318  374  413  405  355  306  271  306
# 1957   315  301  356  348  355  422  465  467  404  347  305  336
# 1958   340  318  362  348  363  435  491  505  404  359  310  337
# 1959   360  342  406  396  420  472  548  559  463  407  362  405
# 1960   417  391  419  461  472  535  622  606  508  461  390  432

# %%
sns.heatmap(x)
# Out:
# <AxesSubplot: xlabel='month', ylabel='year'>

# %%
sns.heatmap(x,cbar=False,linewidths=0.5)
# Out:
# <AxesSubplot: xlabel='month', ylabel='year'>

# %%
sns.heatmap(x,linewidths=0.5,annot=True,fmt='d')
# Out:
# <AxesSubplot: xlabel='month', ylabel='year'>

# %%
sns.heatmap(x,linewidths=0.5,annot=True,fmt='d',cmap='viridis')
# Out:
# <AxesSubplot: xlabel='month', ylabel='year'>

# %%
sns.heatmap(x,linewidths=0.5,annot=True,fmt='d',cmap='summer')
# Out:
# <AxesSubplot: xlabel='month', ylabel='year'>

# %%
sns.heatmap(x,linewidths=0.5,annot=True,fmt='d',cmap='winter')
# Out:
# <AxesSubplot: xlabel='month', ylabel='year'>

# %%
sns.clustermap(x)

# %%
sns.clustermap(x,metric='correlation')

# %%
sns.clustermap(x,metric='correlation',z_score=0,annot=True)

# %%
sns.clustermap(x,metric='correlation',z_score=0,annot=True,row_cluster=False)

# %%
sns.jointplot(data=data,x='total_bill',y='tip') #by default kind is scatter

# %%
sns.jointplot(data=data,x='total_bill',y='tip',kind='hex')

# %%
sns.kdeplot(data=data,x='tip')
# Out:
# <AxesSubplot: xlabel='tip', ylabel='Density'>

# %%
sns.jointplot(data=data,x='total_bill',y='tip',kind='kde')

# %%
#this above thing knowwn as contour which is 2d pdf

# %%
sns.jointplot(data=data,x='total_bill',y='tip',kind='reg')

# %% [markdown]
# # Pairplot

# %%
iris=sns.load_dataset('iris')

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
iris.sample(5)
# Out:
#      sepal_length  sepal_width  petal_length  petal_width     species
# 124           6.7          3.3           5.7          2.1   virginica
# 68            6.2          2.2           4.5          1.5  versicolor
# 59            5.2          2.7           3.9          1.4  versicolor
# 50            7.0          3.2           4.7          1.4  versicolor
# 88            5.6          3.0           4.1          1.3  versicolor

# %%
sns.pairplot(iris) #pairplot figure out what columns are neumerical and accordingly plot the neumerical column

# %%
sns.pairplot(iris,hue='species')

# %% [markdown]
# # Distplot

# %%
titanic=sns.load_dataset('titanic')

# %%
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.7+ KB

# %%
titanic['age'].fillna(titanic['age'].mean(),inplace=True)

# %%
titanic.isnull().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age              0
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %% [markdown]
# # Plotting a distplot

# %%
sns.distplot(titanic['age'])
# Out:
# C:\Users\Riya\AppData\Local\Temp\ipykernel_10260\1132062727.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(titanic['age'])
# <AxesSubplot: xlabel='age', ylabel='Density'>

# %% [markdown]
# # plotting a histogram

# %%
sns.distplot(titanic['age'],kde=False,bins=10)
# Out:
# C:\Users\Riya\AppData\Local\Temp\ipykernel_10260\493000838.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(titanic['age'],kde=False,bins=10)
# <AxesSubplot: xlabel='age'>

# %% [markdown]
# # Plotting the only KDE

# %%
sns.distplot(titanic['age'],hist=False)
# Out:
# C:\Users\Riya\AppData\Local\Temp\ipykernel_10260\3778122104.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(titanic['age'],hist=False)
# <AxesSubplot: xlabel='age', ylabel='Density'>

# %% [markdown]
# # Plotting only the Rugplot

# %%
sns.distplot(titanic['age'],kde=False,hist=False,rug=True)
# Out:
# C:\Users\Riya\AppData\Local\Temp\ipykernel_10260\257785906.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(titanic['age'],kde=False,hist=False,rug=True)
# <AxesSubplot: xlabel='age'>

# %%
   sns.distplot(titanic[titanic['survived']==1]['age'])
# Out:
# C:\Users\Riya\AppData\Local\Temp\ipykernel_10260\1603166872.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(titanic[titanic['survived']==1]['age'])
# <AxesSubplot: xlabel='age', ylabel='Density'>

# %%
    sns.distplot(titanic[titanic['survived']==1]['age'])
    sns.distplot(titanic[titanic['survived']==0]['age'])
# Out:
# C:\Users\Riya\AppData\Local\Temp\ipykernel_10260\3114789426.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(titanic[titanic['survived']==1]['age'])
# C:\Users\Riya\AppData\Local\Temp\ipykernel_10260\3114789426.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
# ...
